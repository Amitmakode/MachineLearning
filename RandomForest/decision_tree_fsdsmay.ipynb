# %%
import pandas as pd
import numpy as np
df=pd.read_csv("https://raw.githubusercontent.com/shrikant-temburwar/Wine-Quality-Dataset/master/winequality-red.csv",sep = ';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
len(df['quality'].unique())
# Out:
# 6

# %%
df['quality'].nunique()
# Out:
# 6

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# fixed acidity          7.90000   9.200000   15.90000
# volatile acidity       0.52000   0.640000    1.58000
# citric acid            0.26000   0.420000    1.00000
# residual sugar         2.20000   2.600000   15.50000
# chlorides              0.07900   0.090000    0.61100
# free sulfur dioxide   14.00000  21.000000   72.00000
# total sulfur dioxide  38.00000  62.000000  289.00000
# density                0.99675   0.997835    1.00369
# pH                     3.31000   3.400000    4.01000
# sulphates              0.62000   0.730000    2.00000
# alcohol               10.20000  11.100000   14.90000
# quality                6.00000   6.000000    8.00000

# %%
df.duplicated().sum()
# Out:
# 240

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
X=df.drop("quality",axis=1)

# %%
y=df['quality']

# %%
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=10)

# %%
'''from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import StandardScaler
sclr = StandardScaler()
scr.fit()
scr.transform()'''
# Out:
# 'from sklearn.preprocessing import StandardScaler\nfrom sklearn.preprocessing import StandardScaler\nsclr = StandardScaler()\nscr.fit()\nscr.transform()'

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_train,y_train)
# Out:
# 1.0

# %%
from sklearn import tree
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(25,15))
tree.plot_tree(model,filled=True)
# Out:
# [Text(0.4982317386831276, 0.9705882352941176, 'X[10] <= 10.15\ngini = 0.645\nsamples = 910\nvalue = [7, 31, 389, 359, 114, 10]'),
#  Text(0.23006687242798354, 0.9117647058823529, 'X[6] <= 62.5\ngini = 0.495\nsamples = 459\nvalue = [3, 15, 298, 131, 12, 0]'),
#  Text(0.12127057613168725, 0.8529411764705882, 'X[1] <= 0.548\ngini = 0.571\nsamples = 282\nvalue = [3, 11, 151, 105, 12, 0]'),
#  Text(0.061921296296296294, 0.7941176470588235, 'X[9] <= 0.585\ngini = 0.596\nsamples = 136\nvalue = [1, 4, 52, 68, 11, 0]'),
#  Text(0.0205761316872428, 0.7352941176470589, 'X[7] <= 0.996\ngini = 0.512\nsamples = 44\nvalue = [0, 4, 28, 12, 0, 0]'),
#  Text(0.00823045267489712, 0.6764705882352942, 'X[9] <= 0.435\ngini = 0.245\nsamples = 14\nvalue = [0, 2, 12, 0, 0, 0]'),
#  Text(0.00411522633744856, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.012345679012345678, 0.6176470588235294, 'X[6] <= 43.0\ngini = 0.142\nsamples = 13\nvalue = [0, 1, 12, 0, 0, 0]'),
#  Text(0.00823045267489712, 0.5588235294117647, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.01646090534979424, 0.5588235294117647, 'X[0] <= 7.25\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.012345679012345678, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.0205761316872428, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.03292181069958848, 0.6764705882352942, 'X[7] <= 0.996\ngini = 0.551\nsamples = 30\nvalue = [0, 2, 16, 12, 0, 0]'),
#  Text(0.02880658436213992, 0.6176470588235294, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.037037037037037035, 0.6176470588235294, 'X[6] <= 59.0\ngini = 0.532\nsamples = 27\nvalue = [0, 2, 16, 9, 0, 0]'),
#  Text(0.03292181069958848, 0.5588235294117647, 'X[3] <= 3.9\ngini = 0.506\nsamples = 25\nvalue = [0, 2, 16, 7, 0, 0]'),
#  Text(0.02880658436213992, 0.5, 'X[3] <= 1.95\ngini = 0.469\nsamples = 24\nvalue = [0, 1, 16, 7, 0, 0]'),
#  Text(0.024691358024691357, 0.4411764705882353, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.03292181069958848, 0.4411764705882353, 'X[10] <= 9.05\ngini = 0.526\nsamples = 19\nvalue = [0, 1, 11, 7, 0, 0]'),
#  Text(0.02880658436213992, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.037037037037037035, 0.38235294117647056, 'X[0] <= 10.65\ngini = 0.491\nsamples = 17\nvalue = [0, 1, 11, 5, 0, 0]'),
#  Text(0.03292181069958848, 0.3235294117647059, 'X[6] <= 52.0\ngini = 0.569\nsamples = 12\nvalue = [0, 1, 6, 5, 0, 0]'),
#  Text(0.02880658436213992, 0.2647058823529412, 'X[2] <= 0.145\ngini = 0.568\nsamples = 9\nvalue = [0, 1, 3, 5, 0, 0]'),
#  Text(0.024691358024691357, 0.20588235294117646, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.03292181069958848, 0.20588235294117646, 'X[4] <= 0.102\ngini = 0.449\nsamples = 7\nvalue = [0, 1, 1, 5, 0, 0]'),
#  Text(0.02880658436213992, 0.14705882352941177, 'X[2] <= 0.505\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(0.024691358024691357, 0.08823529411764706, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.03292181069958848, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.037037037037037035, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.037037037037037035, 0.2647058823529412, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.0411522633744856, 0.3235294117647059, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.037037037037037035, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.0411522633744856, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.1032664609053498, 0.7352941176470589, 'X[7] <= 0.996\ngini = 0.547\nsamples = 92\nvalue = [1, 0, 24, 56, 11, 0]'),
#  Text(0.09915123456790123, 0.6764705882352942, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.10738168724279835, 0.6764705882352942, 'X[0] <= 11.35\ngini = 0.532\nsamples = 90\nvalue = [1, 0, 24, 56, 9, 0]'),
#  Text(0.08719135802469136, 0.6176470588235294, 'X[10] <= 9.95\ngini = 0.533\nsamples = 75\nvalue = [1, 0, 24, 45, 5, 0]'),
#  Text(0.05915637860082305, 0.5588235294117647, 'X[9] <= 0.615\ngini = 0.531\nsamples = 60\nvalue = [1, 0, 23, 34, 2, 0]'),
#  Text(0.04526748971193416, 0.5, 'X[10] <= 9.6\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 6, 1, 0]'),
#  Text(0.0411522633744856, 0.4411764705882353, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.04938271604938271, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.07304526748971193, 0.5, 'X[9] <= 0.645\ngini = 0.532\nsamples = 53\nvalue = [1, 0, 23, 28, 1, 0]'),
#  Text(0.05761316872427984, 0.4411764705882353, 'X[4] <= 0.164\ngini = 0.461\nsamples = 16\nvalue = [0, 0, 11, 4, 1, 0]'),
#  Text(0.053497942386831275, 0.38235294117647056, 'X[8] <= 3.395\ngini = 0.357\nsamples = 14\nvalue = [0, 0, 11, 2, 1, 0]'),
#  Text(0.04938271604938271, 0.3235294117647059, 'X[1] <= 0.51\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 11, 0, 1, 0]'),
#  Text(0.04526748971193416, 0.2647058823529412, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.053497942386831275, 0.2647058823529412, 'X[10] <= 9.45\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.04938271604938271, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.05761316872427984, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.05761316872427984, 0.3235294117647059, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.06172839506172839, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.08847736625514403, 0.4411764705882353, 'X[4] <= 0.084\ngini = 0.473\nsamples = 37\nvalue = [1, 0, 12, 24, 0, 0]'),
#  Text(0.07407407407407407, 0.38235294117647056, 'X[5] <= 22.5\ngini = 0.278\nsamples = 18\nvalue = [0, 0, 3, 15, 0, 0]'),
#  Text(0.06584362139917696, 0.3235294117647059, 'X[5] <= 4.0\ngini = 0.124\nsamples = 15\nvalue = [0, 0, 1, 14, 0, 0]'),
#  Text(0.06172839506172839, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.06995884773662552, 0.2647058823529412, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.0823045267489712, 0.3235294117647059, 'X[0] <= 8.05\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.07818930041152264, 0.2647058823529412, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.08641975308641975, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.102880658436214, 0.38235294117647056, 'X[7] <= 0.998\ngini = 0.548\nsamples = 19\nvalue = [1, 0, 9, 9, 0, 0]'),
#  Text(0.09876543209876543, 0.3235294117647059, 'X[0] <= 7.6\ngini = 0.524\nsamples = 15\nvalue = [1, 0, 5, 9, 0, 0]'),
#  Text(0.09465020576131687, 0.2647058823529412, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.102880658436214, 0.2647058823529412, 'X[9] <= 1.09\ngini = 0.403\nsamples = 12\nvalue = [1, 0, 2, 9, 0, 0]'),
#  Text(0.09876543209876543, 0.20588235294117646, 'X[7] <= 0.998\ngini = 0.18\nsamples = 10\nvalue = [1, 0, 0, 9, 0, 0]'),
#  Text(0.09465020576131687, 0.14705882352941177, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.102880658436214, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.10699588477366255, 0.20588235294117646, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.10699588477366255, 0.3235294117647059, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.11522633744855967, 0.5588235294117647, 'X[6] <= 46.5\ngini = 0.418\nsamples = 15\nvalue = [0, 0, 1, 11, 3, 0]'),
#  Text(0.1111111111111111, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.11934156378600823, 0.5, 'X[9] <= 0.625\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 1, 1, 3, 0]'),
#  Text(0.11522633744855967, 0.4411764705882353, 'X[2] <= 0.285\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.1111111111111111, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.11934156378600823, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.12345679012345678, 0.4411764705882353, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.12757201646090535, 0.6176470588235294, 'X[5] <= 8.0\ngini = 0.391\nsamples = 15\nvalue = [0, 0, 0, 11, 4, 0]'),
#  Text(0.12345679012345678, 0.5588235294117647, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.13168724279835392, 0.5588235294117647, 'X[1] <= 0.295\ngini = 0.49\nsamples = 7\nvalue = [0, 0, 0, 3, 4, 0]'),
#  Text(0.12757201646090535, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.13580246913580246, 0.5, 'X[5] <= 18.0\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.13168724279835392, 0.4411764705882353, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.13991769547325103, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.1806198559670782, 0.7941176470588235, 'X[7] <= 0.996\ngini = 0.473\nsamples = 146\nvalue = [2, 7, 99, 37, 1, 0]'),
#  Text(0.15483539094650206, 0.7352941176470589, 'X[10] <= 9.15\ngini = 0.176\nsamples = 32\nvalue = [1, 1, 29, 1, 0, 0]'),
#  Text(0.14660493827160495, 0.6764705882352942, 'X[5] <= 10.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.14248971193415638, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1507201646090535, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.16306584362139917, 0.6764705882352942, 'X[0] <= 6.75\ngini = 0.064\nsamples = 30\nvalue = [1, 0, 29, 0, 0, 0]'),
#  Text(0.15895061728395063, 0.6176470588235294, 'X[8] <= 3.565\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0, 0, 0]'),
#  Text(0.15483539094650206, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.16306584362139917, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.16718106995884774, 0.6176470588235294, 'gini = 0.0\nsamples = 28\nvalue = [0, 0, 28, 0, 0, 0]'),
#  Text(0.20640432098765432, 0.7352941176470589, 'X[10] <= 9.95\ngini = 0.52\nsamples = 114\nvalue = [1, 6, 70, 36, 1, 0]'),
#  Text(0.18647119341563786, 0.6764705882352942, 'X[8] <= 3.195\ngini = 0.487\nsamples = 95\nvalue = [1, 6, 63, 25, 0, 0]'),
#  Text(0.1823559670781893, 0.6176470588235294, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.19058641975308643, 0.6176470588235294, 'X[1] <= 0.688\ngini = 0.52\nsamples = 85\nvalue = [1, 6, 53, 25, 0, 0]'),
#  Text(0.1712962962962963, 0.5588235294117647, 'X[2] <= 0.28\ngini = 0.544\nsamples = 54\nvalue = [1, 2, 29, 22, 0, 0]'),
#  Text(0.15946502057613168, 0.5, 'X[9] <= 0.535\ngini = 0.491\nsamples = 51\nvalue = [0, 0, 29, 22, 0, 0]'),
#  Text(0.14814814814814814, 0.4411764705882353, 'X[10] <= 9.7\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 7, 1, 0, 0]'),
#  Text(0.1440329218106996, 0.38235294117647056, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.1522633744855967, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.17078189300411523, 0.4411764705882353, 'X[2] <= 0.17\ngini = 0.5\nsamples = 43\nvalue = [0, 0, 22, 21, 0, 0]'),
#  Text(0.16049382716049382, 0.38235294117647056, 'X[0] <= 6.95\ngini = 0.489\nsamples = 33\nvalue = [0, 0, 14, 19, 0, 0]'),
#  Text(0.1522633744855967, 0.3235294117647059, 'X[7] <= 0.997\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.14814814814814814, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.15637860082304528, 0.2647058823529412, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.16872427983539096, 0.3235294117647059, 'X[7] <= 0.997\ngini = 0.444\nsamples = 27\nvalue = [0, 0, 9, 18, 0, 0]'),
#  Text(0.1646090534979424, 0.2647058823529412, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.1728395061728395, 0.2647058823529412, 'X[0] <= 7.25\ngini = 0.498\nsamples = 17\nvalue = [0, 0, 9, 8, 0, 0]'),
#  Text(0.16872427983539096, 0.20588235294117646, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.17695473251028807, 0.20588235294117646, 'X[4] <= 0.077\ngini = 0.473\nsamples = 13\nvalue = [0, 0, 5, 8, 0, 0]'),
#  Text(0.1728395061728395, 0.14705882352941177, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.18106995884773663, 0.14705882352941177, 'X[8] <= 3.3\ngini = 0.397\nsamples = 11\nvalue = [0, 0, 3, 8, 0, 0]'),
#  Text(0.17695473251028807, 0.08823529411764706, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.18518518518518517, 0.08823529411764706, 'X[6] <= 11.5\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 8, 0, 0]'),
#  Text(0.18106995884773663, 0.029411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.18930041152263374, 0.029411764705882353, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.18106995884773663, 0.38235294117647056, 'X[1] <= 0.555\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 8, 2, 0, 0]'),
#  Text(0.17695473251028807, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.18518518518518517, 0.3235294117647059, 'X[6] <= 61.0\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 8, 1, 0, 0]'),
#  Text(0.18106995884773663, 0.2647058823529412, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.18930041152263374, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1831275720164609, 0.5, 'X[2] <= 0.575\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0, 0, 0]'),
#  Text(0.17901234567901234, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.18724279835390947, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.20987654320987653, 0.5588235294117647, 'X[9] <= 0.465\ngini = 0.375\nsamples = 31\nvalue = [0, 4, 24, 3, 0, 0]'),
#  Text(0.205761316872428, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.2139917695473251, 0.5, 'X[0] <= 8.75\ngini = 0.3\nsamples = 29\nvalue = [0, 2, 24, 3, 0, 0]'),
#  Text(0.20164609053497942, 0.4411764705882353, 'X[10] <= 9.05\ngini = 0.15\nsamples = 25\nvalue = [0, 1, 23, 1, 0, 0]'),
#  Text(0.19753086419753085, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.205761316872428, 0.38235294117647056, 'X[6] <= 12.5\ngini = 0.08\nsamples = 24\nvalue = [0, 1, 23, 0, 0, 0]'),
#  Text(0.20164609053497942, 0.3235294117647059, 'X[4] <= 0.082\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.19753086419753085, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.205761316872428, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.20987654320987653, 0.3235294117647059, 'gini = 0.0\nsamples = 22\nvalue = [0, 0, 22, 0, 0, 0]'),
#  Text(0.22633744855967078, 0.4411764705882353, 'X[3] <= 2.45\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 1, 2, 0, 0]'),
#  Text(0.2222222222222222, 0.38235294117647056, 'X[6] <= 26.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.21810699588477367, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.22633744855967078, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.23045267489711935, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.22633744855967078, 0.6764705882352942, 'X[7] <= 0.997\ngini = 0.526\nsamples = 19\nvalue = [0, 0, 7, 11, 1, 0]'),
#  Text(0.2222222222222222, 0.6176470588235294, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.23045267489711935, 0.6176470588235294, 'X[7] <= 0.998\ngini = 0.556\nsamples = 13\nvalue = [0, 0, 7, 5, 1, 0]'),
#  Text(0.22633744855967078, 0.5588235294117647, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.2345679012345679, 0.5588235294117647, 'X[7] <= 0.999\ngini = 0.531\nsamples = 8\nvalue = [0, 0, 2, 5, 1, 0]'),
#  Text(0.23045267489711935, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.23868312757201646, 0.5, 'X[7] <= 1.001\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 0, 1, 0]'),
#  Text(0.2345679012345679, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.24279835390946503, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.33886316872427985, 0.8529411764705882, 'X[6] <= 98.5\ngini = 0.288\nsamples = 177\nvalue = [0, 4, 147, 26, 0, 0]'),
#  Text(0.3001543209876543, 0.7941176470588235, 'X[10] <= 9.45\ngini = 0.39\nsamples = 116\nvalue = [0, 4, 87, 25, 0, 0]'),
#  Text(0.2716049382716049, 0.7352941176470589, 'X[8] <= 3.495\ngini = 0.222\nsamples = 49\nvalue = [0, 2, 43, 4, 0, 0]'),
#  Text(0.26337448559670784, 0.6764705882352942, 'X[4] <= 0.539\ngini = 0.163\nsamples = 46\nvalue = [0, 2, 42, 2, 0, 0]'),
#  Text(0.25925925925925924, 0.6176470588235294, 'X[5] <= 7.0\ngini = 0.126\nsamples = 45\nvalue = [0, 1, 42, 2, 0, 0]'),
#  Text(0.2551440329218107, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.26337448559670784, 0.5588235294117647, 'X[5] <= 11.5\ngini = 0.088\nsamples = 44\nvalue = [0, 1, 42, 1, 0, 0]'),
#  Text(0.2551440329218107, 0.5, 'X[10] <= 9.3\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0, 0, 0]'),
#  Text(0.25102880658436216, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.25925925925925924, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2716049382716049, 0.5, 'X[2] <= 0.09\ngini = 0.048\nsamples = 41\nvalue = [0, 0, 40, 1, 0, 0]'),
#  Text(0.2674897119341564, 0.4411764705882353, 'X[1] <= 0.655\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.26337448559670784, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2716049382716049, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2757201646090535, 0.4411764705882353, 'gini = 0.0\nsamples = 38\nvalue = [0, 0, 38, 0, 0, 0]'),
#  Text(0.2674897119341564, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.27983539094650206, 0.6764705882352942, 'X[3] <= 1.85\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.2757201646090535, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2839506172839506, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.3287037037037037, 0.7352941176470589, 'X[1] <= 0.415\ngini = 0.47\nsamples = 67\nvalue = [0, 2, 44, 21, 0, 0]'),
#  Text(0.2962962962962963, 0.6764705882352942, 'X[1] <= 0.325\ngini = 0.5\nsamples = 14\nvalue = [0, 1, 4, 9, 0, 0]'),
#  Text(0.29218106995884774, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3004115226337449, 0.6176470588235294, 'X[7] <= 0.998\ngini = 0.403\nsamples = 12\nvalue = [0, 1, 2, 9, 0, 0]'),
#  Text(0.29218106995884774, 0.5588235294117647, 'X[3] <= 2.55\ngini = 0.198\nsamples = 9\nvalue = [0, 1, 0, 8, 0, 0]'),
#  Text(0.2880658436213992, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.2962962962962963, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.30864197530864196, 0.5588235294117647, 'X[1] <= 0.355\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.3045267489711934, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.31275720164609055, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3611111111111111, 0.6764705882352942, 'X[8] <= 3.295\ngini = 0.379\nsamples = 53\nvalue = [0, 1, 40, 12, 0, 0]'),
#  Text(0.3395061728395062, 0.6176470588235294, 'X[8] <= 3.205\ngini = 0.5\nsamples = 26\nvalue = [0, 1, 16, 9, 0, 0]'),
#  Text(0.32510288065843623, 0.5588235294117647, 'X[3] <= 2.85\ngini = 0.26\nsamples = 13\nvalue = [0, 0, 11, 2, 0, 0]'),
#  Text(0.32098765432098764, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.3292181069958848, 0.5, 'X[5] <= 38.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.32510288065843623, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.3333333333333333, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.35390946502057613, 0.5588235294117647, 'X[7] <= 0.997\ngini = 0.556\nsamples = 13\nvalue = [0, 1, 5, 7, 0, 0]'),
#  Text(0.345679012345679, 0.5, 'X[10] <= 9.7\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 0, 5, 0, 0]'),
#  Text(0.34156378600823045, 0.4411764705882353, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.3497942386831276, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.36213991769547327, 0.5, 'X[1] <= 0.62\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]'),
#  Text(0.35802469135802467, 0.4411764705882353, 'X[6] <= 80.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.35390946502057613, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.36213991769547327, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3662551440329218, 0.4411764705882353, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.38271604938271603, 0.6176470588235294, 'X[2] <= 0.025\ngini = 0.198\nsamples = 27\nvalue = [0, 0, 24, 3, 0, 0]'),
#  Text(0.37448559670781895, 0.5588235294117647, 'X[10] <= 9.75\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.37037037037037035, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.3786008230452675, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.39094650205761317, 0.5588235294117647, 'X[3] <= 2.75\ngini = 0.087\nsamples = 22\nvalue = [0, 0, 21, 1, 0, 0]'),
#  Text(0.3868312757201646, 0.5, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 19, 0, 0, 0]'),
#  Text(0.3950617283950617, 0.5, 'X[9] <= 0.64\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.39094650205761317, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3991769547325103, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3775720164609053, 0.7941176470588235, 'X[4] <= 0.067\ngini = 0.032\nsamples = 61\nvalue = [0, 0, 60, 1, 0, 0]'),
#  Text(0.3734567901234568, 0.7352941176470589, 'X[6] <= 120.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.36934156378600824, 0.6764705882352942, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3775720164609053, 0.6764705882352942, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3816872427983539, 0.7352941176470589, 'gini = 0.0\nsamples = 59\nvalue = [0, 0, 59, 0, 0, 0]'),
#  Text(0.7663966049382716, 0.9117647058823529, 'X[9] <= 0.675\ngini = 0.651\nsamples = 451\nvalue = [4, 16, 91, 228, 102, 10]'),
#  Text(0.6169624485596708, 0.8529411764705882, 'X[10] <= 11.45\ngini = 0.636\nsamples = 250\nvalue = [4, 16, 69, 130, 29, 2]'),
#  Text(0.5281635802469136, 0.7941176470588235, 'X[1] <= 0.827\ngini = 0.649\nsamples = 157\nvalue = [4, 13, 60, 69, 10, 1]'),
#  Text(0.45550411522633744, 0.7352941176470589, 'X[3] <= 1.85\ngini = 0.589\nsamples = 134\nvalue = [0, 3, 54, 66, 10, 1]'),
#  Text(0.41975308641975306, 0.6764705882352942, 'X[8] <= 3.355\ngini = 0.544\nsamples = 26\nvalue = [0, 0, 16, 6, 4, 0]'),
#  Text(0.411522633744856, 0.6176470588235294, 'X[2] <= 0.405\ngini = 0.661\nsamples = 11\nvalue = [0, 0, 3, 4, 4, 0]'),
#  Text(0.4074074074074074, 0.5588235294117647, 'X[6] <= 32.5\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 0, 4, 4, 0]'),
#  Text(0.40329218106995884, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.411522633744856, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.4156378600823045, 0.5588235294117647, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.4279835390946502, 0.6176470588235294, 'X[8] <= 3.4\ngini = 0.231\nsamples = 15\nvalue = [0, 0, 13, 2, 0, 0]'),
#  Text(0.42386831275720166, 0.5588235294117647, 'X[3] <= 1.75\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(0.41975308641975306, 0.5, 'X[5] <= 12.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.4156378600823045, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.42386831275720166, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.4279835390946502, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.43209876543209874, 0.5588235294117647, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.4912551440329218, 0.6764705882352942, 'X[7] <= 0.996\ngini = 0.564\nsamples = 108\nvalue = [0, 3, 38, 60, 6, 1]'),
#  Text(0.4444444444444444, 0.6176470588235294, 'X[9] <= 0.525\ngini = 0.373\nsamples = 38\nvalue = [0, 0, 8, 29, 1, 0]'),
#  Text(0.4403292181069959, 0.5588235294117647, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.448559670781893, 0.5588235294117647, 'X[5] <= 4.5\ngini = 0.292\nsamples = 35\nvalue = [0, 0, 5, 29, 1, 0]'),
#  Text(0.4444444444444444, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.45267489711934156, 0.5, 'X[7] <= 0.995\ngini = 0.251\nsamples = 34\nvalue = [0, 0, 5, 29, 0, 0]'),
#  Text(0.4403292181069959, 0.4411764705882353, 'X[8] <= 3.345\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.43621399176954734, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.4444444444444444, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.46502057613168724, 0.4411764705882353, 'X[5] <= 7.0\ngini = 0.18\nsamples = 30\nvalue = [0, 0, 3, 27, 0, 0]'),
#  Text(0.45267489711934156, 0.38235294117647056, 'X[1] <= 0.395\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 2, 4, 0, 0]'),
#  Text(0.448559670781893, 0.3235294117647059, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.4567901234567901, 0.3235294117647059, 'X[1] <= 0.702\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.45267489711934156, 0.2647058823529412, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.4609053497942387, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4773662551440329, 0.38235294117647056, 'X[6] <= 26.5\ngini = 0.08\nsamples = 24\nvalue = [0, 0, 1, 23, 0, 0]'),
#  Text(0.4732510288065844, 0.3235294117647059, 'X[5] <= 14.5\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.4691358024691358, 0.2647058823529412, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.4773662551440329, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.48148148148148145, 0.3235294117647059, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 0, 19, 0, 0]'),
#  Text(0.5380658436213992, 0.6176470588235294, 'X[6] <= 42.5\ngini = 0.613\nsamples = 70\nvalue = [0, 3, 30, 31, 5, 1]'),
#  Text(0.5164609053497943, 0.5588235294117647, 'X[3] <= 2.15\ngini = 0.629\nsamples = 46\nvalue = [0, 2, 23, 15, 5, 1]'),
#  Text(0.5082304526748971, 0.5, 'X[9] <= 0.66\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(0.5041152263374485, 0.4411764705882353, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.5123456790123457, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5246913580246914, 0.5, 'X[1] <= 0.78\ngini = 0.616\nsamples = 40\nvalue = [0, 2, 22, 10, 5, 1]'),
#  Text(0.5205761316872428, 0.4411764705882353, 'X[10] <= 10.55\ngini = 0.6\nsamples = 38\nvalue = [0, 2, 22, 8, 5, 1]'),
#  Text(0.49794238683127573, 0.38235294117647056, 'X[6] <= 37.5\ngini = 0.32\nsamples = 16\nvalue = [0, 0, 13, 2, 1, 0]'),
#  Text(0.4897119341563786, 0.3235294117647059, 'X[8] <= 3.485\ngini = 0.142\nsamples = 13\nvalue = [0, 0, 12, 0, 1, 0]'),
#  Text(0.48559670781893005, 0.2647058823529412, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]'),
#  Text(0.49382716049382713, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5061728395061729, 0.3235294117647059, 'X[1] <= 0.465\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.5020576131687243, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5102880658436214, 0.2647058823529412, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5432098765432098, 0.38235294117647056, 'X[9] <= 0.625\ngini = 0.715\nsamples = 22\nvalue = [0, 2, 9, 6, 4, 1]'),
#  Text(0.5267489711934157, 0.3235294117647059, 'X[4] <= 0.081\ngini = 0.602\nsamples = 16\nvalue = [0, 1, 8, 6, 1, 0]'),
#  Text(0.5185185185185185, 0.2647058823529412, 'X[7] <= 0.996\ngini = 0.449\nsamples = 7\nvalue = [0, 1, 5, 0, 1, 0]'),
#  Text(0.51440329218107, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.522633744855967, 0.20588235294117646, 'X[8] <= 3.37\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 5, 0, 0, 0]'),
#  Text(0.5185185185185185, 0.14705882352941177, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.5267489711934157, 0.14705882352941177, 'X[4] <= 0.056\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.522633744855967, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5308641975308642, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5349794238683128, 0.2647058823529412, 'X[4] <= 0.094\ngini = 0.444\nsamples = 9\nvalue = [0, 0, 3, 6, 0, 0]'),
#  Text(0.5308641975308642, 0.20588235294117646, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.5390946502057613, 0.20588235294117646, 'X[4] <= 0.103\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.5349794238683128, 0.14705882352941177, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.5432098765432098, 0.14705882352941177, 'X[0] <= 9.15\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.5390946502057613, 0.08823529411764706, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5473251028806584, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5596707818930041, 0.3235294117647059, 'X[4] <= 0.102\ngini = 0.667\nsamples = 6\nvalue = [0, 1, 1, 0, 3, 1]'),
#  Text(0.551440329218107, 0.2647058823529412, 'X[1] <= 0.36\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 0, 3, 1]'),
#  Text(0.5473251028806584, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.5555555555555556, 0.20588235294117646, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.5679012345679012, 0.2647058823529412, 'X[10] <= 10.9\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.5637860082304527, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5720164609053497, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5288065843621399, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5596707818930041, 0.5588235294117647, 'X[3] <= 2.05\ngini = 0.469\nsamples = 24\nvalue = [0, 1, 7, 16, 0, 0]'),
#  Text(0.551440329218107, 0.5, 'X[8] <= 3.225\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4, 0, 0, 0]'),
#  Text(0.5473251028806584, 0.4411764705882353, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.5555555555555556, 0.4411764705882353, 'X[8] <= 3.34\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.551440329218107, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5596707818930041, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5679012345679012, 0.5, 'X[5] <= 27.5\ngini = 0.266\nsamples = 19\nvalue = [0, 0, 3, 16, 0, 0]'),
#  Text(0.5637860082304527, 0.4411764705882353, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.5720164609053497, 0.4411764705882353, 'X[3] <= 2.85\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.5679012345679012, 0.38235294117647056, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.5761316872427984, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.6008230452674898, 0.7352941176470589, 'X[10] <= 10.95\ngini = 0.696\nsamples = 23\nvalue = [4, 10, 6, 3, 0, 0]'),
#  Text(0.588477366255144, 0.6764705882352942, 'X[4] <= 0.075\ngini = 0.722\nsamples = 13\nvalue = [3, 2, 5, 3, 0, 0]'),
#  Text(0.5761316872427984, 0.6176470588235294, 'X[8] <= 3.52\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 0, 3, 0, 0]'),
#  Text(0.5720164609053497, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5802469135802469, 0.5588235294117647, 'X[3] <= 2.15\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 1, 0, 0]'),
#  Text(0.5761316872427984, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.5843621399176955, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6008230452674898, 0.6176470588235294, 'X[3] <= 3.275\ngini = 0.469\nsamples = 8\nvalue = [3, 0, 5, 0, 0, 0]'),
#  Text(0.5967078189300411, 0.5588235294117647, 'X[7] <= 0.995\ngini = 0.278\nsamples = 6\nvalue = [1, 0, 5, 0, 0, 0]'),
#  Text(0.5925925925925926, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.6008230452674898, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.6049382716049383, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0]'),
#  Text(0.6131687242798354, 0.6764705882352942, 'X[6] <= 11.5\ngini = 0.34\nsamples = 10\nvalue = [1, 8, 1, 0, 0, 0]'),
#  Text(0.6090534979423868, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.6172839506172839, 0.6176470588235294, 'X[2] <= 0.255\ngini = 0.198\nsamples = 9\nvalue = [0, 8, 1, 0, 0, 0]'),
#  Text(0.6131687242798354, 0.5588235294117647, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0, 0, 0]'),
#  Text(0.6213991769547325, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7057613168724279, 0.7941176470588235, 'X[3] <= 4.5\ngini = 0.518\nsamples = 93\nvalue = [0, 3, 9, 61, 19, 1]'),
#  Text(0.6748971193415638, 0.7352941176470589, 'X[6] <= 15.5\ngini = 0.442\nsamples = 80\nvalue = [0, 1, 8, 58, 12, 1]'),
#  Text(0.6440329218106996, 0.6764705882352942, 'X[9] <= 0.545\ngini = 0.626\nsamples = 19\nvalue = [0, 1, 2, 9, 7, 0]'),
#  Text(0.6337448559670782, 0.6176470588235294, 'X[1] <= 0.58\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 1, 6, 0, 0]'),
#  Text(0.6296296296296297, 0.5588235294117647, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.6378600823045267, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.654320987654321, 0.6176470588235294, 'X[7] <= 0.995\ngini = 0.583\nsamples = 12\nvalue = [0, 1, 1, 3, 7, 0]'),
#  Text(0.6460905349794238, 0.5588235294117647, 'X[10] <= 12.85\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 1, 0, 6, 0]'),
#  Text(0.6419753086419753, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.6502057613168725, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6625514403292181, 0.5588235294117647, 'X[2] <= 0.145\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 0, 3, 1, 0]'),
#  Text(0.6584362139917695, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.6666666666666666, 0.5, 'X[8] <= 3.18\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.6625514403292181, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.6707818930041153, 0.4411764705882353, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.7057613168724279, 0.6764705882352942, 'X[5] <= 41.25\ngini = 0.338\nsamples = 61\nvalue = [0, 0, 6, 49, 5, 1]'),
#  Text(0.7016460905349794, 0.6176470588235294, 'X[4] <= 0.058\ngini = 0.316\nsamples = 60\nvalue = [0, 0, 6, 49, 5, 0]'),
#  Text(0.691358024691358, 0.5588235294117647, 'X[5] <= 14.0\ngini = 0.475\nsamples = 18\nvalue = [0, 0, 5, 12, 1, 0]'),
#  Text(0.6831275720164609, 0.5, 'X[4] <= 0.047\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(0.6790123456790124, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.6872427983539094, 0.4411764705882353, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.6995884773662552, 0.5, 'X[10] <= 12.9\ngini = 0.292\nsamples = 12\nvalue = [0, 0, 1, 10, 1, 0]'),
#  Text(0.6954732510288066, 0.4411764705882353, 'X[6] <= 97.0\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 0, 10, 1, 0]'),
#  Text(0.691358024691358, 0.38235294117647056, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.6995884773662552, 0.38235294117647056, 'X[2] <= 0.205\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.6954732510288066, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7037037037037037, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7037037037037037, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7119341563786008, 0.5588235294117647, 'X[9] <= 0.605\ngini = 0.214\nsamples = 42\nvalue = [0, 0, 1, 37, 4, 0]'),
#  Text(0.7078189300411523, 0.5, 'gini = 0.0\nsamples = 24\nvalue = [0, 0, 0, 24, 0, 0]'),
#  Text(0.7160493827160493, 0.5, 'X[10] <= 12.35\ngini = 0.426\nsamples = 18\nvalue = [0, 0, 1, 13, 4, 0]'),
#  Text(0.7119341563786008, 0.4411764705882353, 'X[7] <= 0.995\ngini = 0.58\nsamples = 10\nvalue = [0, 0, 1, 5, 4, 0]'),
#  Text(0.7078189300411523, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.7160493827160493, 0.38235294117647056, 'X[1] <= 0.46\ngini = 0.531\nsamples = 8\nvalue = [0, 0, 1, 5, 2, 0]'),
#  Text(0.7119341563786008, 0.3235294117647059, 'X[5] <= 10.5\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 1, 2, 0]'),
#  Text(0.7078189300411523, 0.2647058823529412, 'X[7] <= 0.996\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.7037037037037037, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7119341563786008, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7160493827160493, 0.2647058823529412, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.720164609053498, 0.3235294117647059, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.720164609053498, 0.4411764705882353, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.7098765432098766, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.7366255144032922, 0.7352941176470589, 'X[2] <= 0.405\ngini = 0.627\nsamples = 13\nvalue = [0, 2, 1, 3, 7, 0]'),
#  Text(0.7283950617283951, 0.6764705882352942, 'X[2] <= 0.275\ngini = 0.64\nsamples = 5\nvalue = [0, 2, 1, 2, 0, 0]'),
#  Text(0.7242798353909465, 0.6176470588235294, 'X[4] <= 0.078\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.720164609053498, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7283950617283951, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7325102880658436, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.7448559670781894, 0.6764705882352942, 'X[4] <= 0.106\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 1, 7, 0]'),
#  Text(0.7407407407407407, 0.6176470588235294, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.7489711934156379, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9158307613168725, 0.8529411764705882, 'X[10] <= 12.05\ngini = 0.617\nsamples = 201\nvalue = [0, 0, 22, 98, 73, 8]'),
#  Text(0.8501800411522634, 0.7941176470588235, 'X[1] <= 0.335\ngini = 0.589\nsamples = 164\nvalue = [0, 0, 21, 90, 50, 3]'),
#  Text(0.7849794238683128, 0.7352941176470589, 'X[9] <= 0.735\ngini = 0.59\nsamples = 50\nvalue = [0, 0, 5, 18, 26, 1]'),
#  Text(0.7654320987654321, 0.6764705882352942, 'X[5] <= 10.5\ngini = 0.5\nsamples = 12\nvalue = [0, 0, 2, 8, 2, 0]'),
#  Text(0.757201646090535, 0.6176470588235294, 'X[7] <= 0.995\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 1, 0]'),
#  Text(0.7530864197530864, 0.5588235294117647, 'X[5] <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.7489711934156379, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.757201646090535, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7613168724279835, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.7736625514403292, 0.6176470588235294, 'X[7] <= 0.998\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 7, 1, 0]'),
#  Text(0.7695473251028807, 0.5588235294117647, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.7777777777777778, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8045267489711934, 0.6764705882352942, 'X[10] <= 10.4\ngini = 0.525\nsamples = 38\nvalue = [0, 0, 3, 10, 24, 1]'),
#  Text(0.7901234567901234, 0.6176470588235294, 'X[6] <= 64.0\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 5, 1, 0]'),
#  Text(0.7860082304526749, 0.5588235294117647, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.7942386831275721, 0.5588235294117647, 'X[4] <= 0.066\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.7901234567901234, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7983539094650206, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8189300411522634, 0.6176470588235294, 'X[4] <= 0.12\ngini = 0.449\nsamples = 32\nvalue = [0, 0, 3, 5, 23, 1]'),
#  Text(0.8148148148148148, 0.5588235294117647, 'X[6] <= 53.5\ngini = 0.391\nsamples = 30\nvalue = [0, 0, 3, 3, 23, 1]'),
#  Text(0.8065843621399177, 0.5, 'X[3] <= 1.65\ngini = 0.288\nsamples = 24\nvalue = [0, 0, 0, 3, 20, 1]'),
#  Text(0.8024691358024691, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8106995884773662, 0.4411764705882353, 'X[2] <= 0.475\ngini = 0.234\nsamples = 23\nvalue = [0, 0, 0, 2, 20, 1]'),
#  Text(0.8065843621399177, 0.38235294117647056, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 0, 14, 0]'),
#  Text(0.8148148148148148, 0.38235294117647056, 'X[10] <= 11.45\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 0, 2, 6, 1]'),
#  Text(0.8106995884773662, 0.3235294117647059, 'X[1] <= 0.275\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 0, 2, 6, 0]'),
#  Text(0.8065843621399177, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8148148148148148, 0.2647058823529412, 'X[0] <= 10.8\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 1, 6, 0]'),
#  Text(0.8106995884773662, 0.20588235294117646, 'X[9] <= 0.8\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.8065843621399177, 0.14705882352941177, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8148148148148148, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8189300411522634, 0.20588235294117646, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.8189300411522634, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.823045267489712, 0.5, 'X[6] <= 72.0\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 0, 3, 0]'),
#  Text(0.8189300411522634, 0.4411764705882353, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.8271604938271605, 0.4411764705882353, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.823045267489712, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.915380658436214, 0.7352941176470589, 'X[3] <= 4.4\ngini = 0.537\nsamples = 114\nvalue = [0, 0, 16, 72, 24, 2]'),
#  Text(0.8883744855967078, 0.6764705882352942, 'X[2] <= 0.56\ngini = 0.484\nsamples = 104\nvalue = [0, 0, 10, 71, 21, 2]'),
#  Text(0.8734567901234568, 0.6176470588235294, 'X[1] <= 0.875\ngini = 0.431\nsamples = 90\nvalue = [0, 0, 9, 66, 13, 2]'),
#  Text(0.8693415637860082, 0.5588235294117647, 'X[4] <= 0.071\ngini = 0.409\nsamples = 88\nvalue = [0, 0, 7, 66, 13, 2]'),
#  Text(0.8580246913580247, 0.5, 'X[1] <= 0.555\ngini = 0.542\nsamples = 34\nvalue = [0, 0, 2, 21, 9, 2]'),
#  Text(0.8477366255144033, 0.4411764705882353, 'X[9] <= 0.825\ngini = 0.464\nsamples = 27\nvalue = [0, 0, 1, 19, 5, 2]'),
#  Text(0.8395061728395061, 0.38235294117647056, 'X[9] <= 0.815\ngini = 0.602\nsamples = 16\nvalue = [0, 0, 1, 9, 4, 2]'),
#  Text(0.8353909465020576, 0.3235294117647059, 'X[7] <= 0.996\ngini = 0.541\nsamples = 14\nvalue = [0, 0, 1, 9, 2, 2]'),
#  Text(0.831275720164609, 0.2647058823529412, 'X[6] <= 40.0\ngini = 0.719\nsamples = 8\nvalue = [0, 0, 1, 3, 2, 2]'),
#  Text(0.8271604938271605, 0.20588235294117646, 'X[1] <= 0.425\ngini = 0.64\nsamples = 5\nvalue = [0, 0, 1, 0, 2, 2]'),
#  Text(0.823045267489712, 0.14705882352941177, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.831275720164609, 0.14705882352941177, 'X[3] <= 2.25\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]'),
#  Text(0.8271604938271605, 0.08823529411764706, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8353909465020576, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8353909465020576, 0.20588235294117646, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.8395061728395061, 0.2647058823529412, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.8436213991769548, 0.3235294117647059, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8559670781893004, 0.38235294117647056, 'X[4] <= 0.07\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 0, 10, 1, 0]'),
#  Text(0.8518518518518519, 0.3235294117647059, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.8600823045267489, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8683127572016461, 0.4411764705882353, 'X[4] <= 0.061\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 1, 2, 4, 0]'),
#  Text(0.8641975308641975, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8724279835390947, 0.38235294117647056, 'X[2] <= 0.33\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 0, 4, 0]'),
#  Text(0.8683127572016461, 0.3235294117647059, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.8765432098765432, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8806584362139918, 0.5, 'X[1] <= 0.345\ngini = 0.291\nsamples = 54\nvalue = [0, 0, 5, 45, 4, 0]'),
#  Text(0.8765432098765432, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8847736625514403, 0.4411764705882353, 'X[0] <= 6.0\ngini = 0.268\nsamples = 53\nvalue = [0, 0, 4, 45, 4, 0]'),
#  Text(0.8806584362139918, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8888888888888888, 0.38235294117647056, 'X[7] <= 1.002\ngini = 0.242\nsamples = 52\nvalue = [0, 0, 3, 45, 4, 0]'),
#  Text(0.8847736625514403, 0.3235294117647059, 'X[9] <= 0.845\ngini = 0.214\nsamples = 51\nvalue = [0, 0, 2, 45, 4, 0]'),
#  Text(0.8703703703703703, 0.2647058823529412, 'X[4] <= 0.123\ngini = 0.141\nsamples = 40\nvalue = [0, 0, 1, 37, 2, 0]'),
#  Text(0.8621399176954733, 0.20588235294117646, 'X[10] <= 11.65\ngini = 0.1\nsamples = 38\nvalue = [0, 0, 0, 36, 2, 0]'),
#  Text(0.8580246913580247, 0.14705882352941177, 'gini = 0.0\nsamples = 31\nvalue = [0, 0, 0, 31, 0, 0]'),
#  Text(0.8662551440329218, 0.14705882352941177, 'X[10] <= 11.85\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 0, 5, 2, 0]'),
#  Text(0.8621399176954733, 0.08823529411764706, 'X[7] <= 0.996\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.8580246913580247, 0.029411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8662551440329218, 0.029411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8703703703703703, 0.08823529411764706, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.8786008230452675, 0.20588235294117646, 'X[7] <= 0.998\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.8744855967078189, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8827160493827161, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8991769547325102, 0.2647058823529412, 'X[9] <= 0.885\ngini = 0.43\nsamples = 11\nvalue = [0, 0, 1, 8, 2, 0]'),
#  Text(0.8950617283950617, 0.20588235294117646, 'X[8] <= 3.305\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 1, 2, 0]'),
#  Text(0.8909465020576132, 0.14705882352941177, 'X[3] <= 2.75\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.8868312757201646, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8950617283950617, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8991769547325102, 0.14705882352941177, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9032921810699589, 0.20588235294117646, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.8930041152263375, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8775720164609053, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.9032921810699589, 0.6176470588235294, 'X[7] <= 0.998\ngini = 0.541\nsamples = 14\nvalue = [0, 0, 1, 5, 8, 0]'),
#  Text(0.8930041152263375, 0.5588235294117647, 'X[4] <= 0.147\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 1, 6, 0]'),
#  Text(0.8888888888888888, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.897119341563786, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9135802469135802, 0.5588235294117647, 'X[10] <= 10.65\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 1, 4, 2, 0]'),
#  Text(0.9053497942386831, 0.5, 'X[0] <= 12.2\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.9012345679012346, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9094650205761317, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9218106995884774, 0.5, 'X[9] <= 0.685\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 1, 0]'),
#  Text(0.9176954732510288, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9259259259259259, 0.4411764705882353, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.9423868312757202, 0.6764705882352942, 'X[6] <= 52.5\ngini = 0.54\nsamples = 10\nvalue = [0, 0, 6, 1, 3, 0]'),
#  Text(0.9382716049382716, 0.6176470588235294, 'X[8] <= 3.285\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 1, 1, 3, 0]'),
#  Text(0.934156378600823, 0.5588235294117647, 'X[2] <= 0.495\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.9300411522633745, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9382716049382716, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9423868312757202, 0.5588235294117647, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.9465020576131687, 0.6176470588235294, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.9814814814814815, 0.7941176470588235, 'X[9] <= 0.905\ngini = 0.548\nsamples = 37\nvalue = [0, 0, 1, 8, 23, 5]'),
#  Text(0.977366255144033, 0.7352941176470589, 'X[10] <= 13.8\ngini = 0.498\nsamples = 34\nvalue = [0, 0, 1, 5, 23, 5]'),
#  Text(0.9629629629629629, 0.6764705882352942, 'X[2] <= 0.565\ngini = 0.4\nsamples = 29\nvalue = [0, 0, 1, 2, 22, 4]'),
#  Text(0.9547325102880658, 0.6176470588235294, 'X[5] <= 31.5\ngini = 0.313\nsamples = 27\nvalue = [0, 0, 0, 1, 22, 4]'),
#  Text(0.9506172839506173, 0.5588235294117647, 'X[3] <= 6.3\ngini = 0.269\nsamples = 26\nvalue = [0, 0, 0, 1, 22, 3]'),
#  Text(0.9465020576131687, 0.5, 'X[4] <= 0.076\ngini = 0.218\nsamples = 25\nvalue = [0, 0, 0, 1, 22, 2]'),
#  Text(0.9382716049382716, 0.4411764705882353, 'X[9] <= 0.705\ngini = 0.1\nsamples = 19\nvalue = [0, 0, 0, 1, 18, 0]'),
#  Text(0.934156378600823, 0.38235294117647056, 'X[8] <= 3.34\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.9300411522633745, 0.3235294117647059, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9382716049382716, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9423868312757202, 0.38235294117647056, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 0, 0, 16, 0]'),
#  Text(0.9547325102880658, 0.4411764705882353, 'X[10] <= 12.7\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 0, 0, 4, 2]'),
#  Text(0.9506172839506173, 0.38235294117647056, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.9588477366255144, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.9547325102880658, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9588477366255144, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9711934156378601, 0.6176470588235294, 'X[3] <= 3.4\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.9670781893004116, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9753086419753086, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9917695473251029, 0.6764705882352942, 'X[8] <= 3.705\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 0, 3, 1, 1]'),
#  Text(0.9876543209876543, 0.6176470588235294, 'X[9] <= 0.805\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 0, 1]'),
#  Text(0.9835390946502057, 0.5588235294117647, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9917695473251029, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9958847736625515, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.98559670781893, 0.7352941176470589, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]')]

# %%
fig.savefig("decistion_tree_classifier.png")

# %%
y_predict=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.48775055679287305

# %%
grid_param = {
    'criterion': ['gini', 'entropy'],
    'max_depth' : range(2,10,1),
    'min_samples_leaf' : range(1,8,1),
    'min_samples_split': range(2,8,1),
    'splitter' : ['best', 'random']
    
}

# %%
from sklearn.model_selection import GridSearchCV
grid_searh=GridSearchCV(estimator=model,param_grid=grid_param,cv=3,verbose=1)

# %%
grid_searh.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 1344 candidates, totalling 4032 fits
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 10),
#                          'min_samples_leaf': range(1, 8),
#                          'min_samples_split': range(2, 8),
#                          'splitter': ['best', 'random']},
#              verbose=1)

# %%
grid_searh.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 8,
#  'min_samples_leaf': 4,
#  'min_samples_split': 2,
#  'splitter': 'random'}

# %%
model_with_best_params=DecisionTreeClassifier(criterion= 'entropy',max_depth= 8,min_samples_leaf= 4,min_samples_split= 2,splitter='random')

# %%
model_with_best_params.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=8, min_samples_leaf=4,
#                        splitter='random')

# %%
from sklearn import tree
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(25,15))
tree.plot_tree(model_with_best_params,filled=True,fontsize=10)
# Out:
# [Text(0.4427510245901639, 0.9444444444444444, 'X[6] <= 24.861\nentropy = 1.721\nsamples = 910\nvalue = [7, 31, 389, 359, 114, 10]'),
#  Text(0.20440573770491804, 0.8333333333333334, 'X[1] <= 0.549\nentropy = 1.956\nsamples = 254\nvalue = [5, 13, 76, 104, 51, 5]'),
#  Text(0.07479508196721311, 0.7222222222222222, 'X[4] <= 0.061\nentropy = 1.736\nsamples = 165\nvalue = [0, 3, 35, 81, 41, 5]'),
#  Text(0.02459016393442623, 0.6111111111111112, 'X[8] <= 3.311\nentropy = 1.433\nsamples = 22\nvalue = [0, 1, 1, 11, 9, 0]'),
#  Text(0.01639344262295082, 0.5, 'X[6] <= 12.413\nentropy = 1.531\nsamples = 16\nvalue = [0, 1, 1, 8, 6, 0]'),
#  Text(0.00819672131147541, 0.3888888888888889, 'entropy = 1.406\nsamples = 8\nvalue = [0, 1, 0, 3, 4, 0]'),
#  Text(0.02459016393442623, 0.3888888888888889, 'entropy = 1.299\nsamples = 8\nvalue = [0, 0, 1, 5, 2, 0]'),
#  Text(0.03278688524590164, 0.5, 'entropy = 1.0\nsamples = 6\nvalue = [0, 0, 0, 3, 3, 0]'),
#  Text(0.125, 0.6111111111111112, 'X[9] <= 0.592\nentropy = 1.736\nsamples = 143\nvalue = [0, 2, 34, 70, 32, 5]'),
#  Text(0.05737704918032787, 0.5, 'X[10] <= 9.817\nentropy = 1.688\nsamples = 39\nvalue = [0, 2, 17, 14, 6, 0]'),
#  Text(0.040983606557377046, 0.3888888888888889, 'X[9] <= 0.524\nentropy = 0.817\nsamples = 12\nvalue = [0, 1, 10, 1, 0, 0]'),
#  Text(0.03278688524590164, 0.2777777777777778, 'entropy = 0.722\nsamples = 5\nvalue = [0, 1, 4, 0, 0, 0]'),
#  Text(0.04918032786885246, 0.2777777777777778, 'entropy = 0.592\nsamples = 7\nvalue = [0, 0, 6, 1, 0, 0]'),
#  Text(0.07377049180327869, 0.3888888888888889, 'X[7] <= 0.997\nentropy = 1.671\nsamples = 27\nvalue = [0, 1, 7, 13, 6, 0]'),
#  Text(0.06557377049180328, 0.2777777777777778, 'X[7] <= 0.996\nentropy = 1.406\nsamples = 20\nvalue = [0, 0, 3, 11, 6, 0]'),
#  Text(0.04918032786885246, 0.16666666666666666, 'X[0] <= 8.751\nentropy = 1.53\nsamples = 9\nvalue = [0, 0, 2, 3, 4, 0]'),
#  Text(0.040983606557377046, 0.05555555555555555, 'entropy = 1.371\nsamples = 5\nvalue = [0, 0, 1, 3, 1, 0]'),
#  Text(0.05737704918032787, 0.05555555555555555, 'entropy = 0.811\nsamples = 4\nvalue = [0, 0, 1, 0, 3, 0]'),
#  Text(0.08196721311475409, 0.16666666666666666, 'X[3] <= 2.355\nentropy = 1.096\nsamples = 11\nvalue = [0, 0, 1, 8, 2, 0]'),
#  Text(0.07377049180327869, 0.05555555555555555, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.09016393442622951, 0.05555555555555555, 'entropy = 1.459\nsamples = 6\nvalue = [0, 0, 1, 3, 2, 0]'),
#  Text(0.08196721311475409, 0.2777777777777778, 'entropy = 1.379\nsamples = 7\nvalue = [0, 1, 4, 2, 0, 0]'),
#  Text(0.19262295081967212, 0.5, 'X[10] <= 12.268\nentropy = 1.619\nsamples = 104\nvalue = [0, 0, 17, 56, 26, 5]'),
#  Text(0.16393442622950818, 0.3888888888888889, 'X[10] <= 10.141\nentropy = 1.56\nsamples = 95\nvalue = [0, 0, 17, 53, 22, 3]'),
#  Text(0.13114754098360656, 0.2777777777777778, 'X[1] <= 0.309\nentropy = 1.164\nsamples = 32\nvalue = [0, 0, 9, 21, 2, 0]'),
#  Text(0.11475409836065574, 0.16666666666666666, 'X[3] <= 1.8\nentropy = 1.157\nsamples = 10\nvalue = [0, 0, 1, 7, 2, 0]'),
#  Text(0.10655737704918032, 0.05555555555555555, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.12295081967213115, 0.05555555555555555, 'entropy = 1.522\nsamples = 5\nvalue = [0, 0, 1, 2, 2, 0]'),
#  Text(0.14754098360655737, 0.16666666666666666, 'X[7] <= 0.999\nentropy = 0.946\nsamples = 22\nvalue = [0, 0, 8, 14, 0, 0]'),
#  Text(0.13934426229508196, 0.05555555555555555, 'entropy = 0.989\nsamples = 16\nvalue = [0, 0, 7, 9, 0, 0]'),
#  Text(0.1557377049180328, 0.05555555555555555, 'entropy = 0.65\nsamples = 6\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(0.19672131147540983, 0.2777777777777778, 'X[4] <= 0.076\nentropy = 1.609\nsamples = 63\nvalue = [0, 0, 8, 32, 20, 3]'),
#  Text(0.18032786885245902, 0.16666666666666666, 'X[9] <= 0.656\nentropy = 1.379\nsamples = 27\nvalue = [0, 0, 1, 17, 7, 2]'),
#  Text(0.1721311475409836, 0.05555555555555555, 'entropy = 1.922\nsamples = 5\nvalue = [0, 0, 1, 2, 1, 1]'),
#  Text(0.1885245901639344, 0.05555555555555555, 'entropy = 1.091\nsamples = 22\nvalue = [0, 0, 0, 15, 6, 1]'),
#  Text(0.21311475409836064, 0.16666666666666666, 'X[3] <= 2.528\nentropy = 1.66\nsamples = 36\nvalue = [0, 0, 7, 15, 13, 1]'),
#  Text(0.20491803278688525, 0.05555555555555555, 'entropy = 1.447\nsamples = 17\nvalue = [0, 0, 5, 9, 3, 0]'),
#  Text(0.22131147540983606, 0.05555555555555555, 'entropy = 1.578\nsamples = 19\nvalue = [0, 0, 2, 6, 10, 1]'),
#  Text(0.22131147540983606, 0.3888888888888889, 'X[1] <= 0.363\nentropy = 1.53\nsamples = 9\nvalue = [0, 0, 0, 3, 4, 2]'),
#  Text(0.21311475409836064, 0.2777777777777778, 'entropy = 0.722\nsamples = 5\nvalue = [0, 0, 0, 0, 4, 1]'),
#  Text(0.22950819672131148, 0.2777777777777778, 'entropy = 0.811\nsamples = 4\nvalue = [0, 0, 0, 3, 0, 1]'),
#  Text(0.33401639344262296, 0.7222222222222222, 'X[6] <= 15.576\nentropy = 1.962\nsamples = 89\nvalue = [5, 10, 41, 23, 10, 0]'),
#  Text(0.29918032786885246, 0.6111111111111112, 'X[9] <= 0.604\nentropy = 2.073\nsamples = 50\nvalue = [5, 8, 22, 10, 5, 0]'),
#  Text(0.2786885245901639, 0.5, 'X[1] <= 0.959\nentropy = 1.838\nsamples = 36\nvalue = [4, 6, 20, 4, 2, 0]'),
#  Text(0.27049180327868855, 0.3888888888888889, 'X[7] <= 0.996\nentropy = 1.685\nsamples = 30\nvalue = [1, 5, 18, 4, 2, 0]'),
#  Text(0.2540983606557377, 0.2777777777777778, 'X[4] <= 0.082\nentropy = 1.405\nsamples = 18\nvalue = [0, 1, 12, 3, 2, 0]'),
#  Text(0.2459016393442623, 0.16666666666666666, 'X[8] <= 3.503\nentropy = 1.095\nsamples = 14\nvalue = [0, 1, 10, 3, 0, 0]'),
#  Text(0.23770491803278687, 0.05555555555555555, 'entropy = 0.922\nsamples = 10\nvalue = [0, 1, 8, 1, 0, 0]'),
#  Text(0.2540983606557377, 0.05555555555555555, 'entropy = 1.0\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.26229508196721313, 0.16666666666666666, 'entropy = 1.0\nsamples = 4\nvalue = [0, 0, 2, 0, 2, 0]'),
#  Text(0.28688524590163933, 0.2777777777777778, 'X[10] <= 9.848\nentropy = 1.626\nsamples = 12\nvalue = [1, 4, 6, 1, 0, 0]'),
#  Text(0.2786885245901639, 0.16666666666666666, 'X[0] <= 7.706\nentropy = 0.811\nsamples = 8\nvalue = [0, 2, 6, 0, 0, 0]'),
#  Text(0.27049180327868855, 0.05555555555555555, 'entropy = 0.811\nsamples = 4\nvalue = [0, 1, 3, 0, 0, 0]'),
#  Text(0.28688524590163933, 0.05555555555555555, 'entropy = 0.811\nsamples = 4\nvalue = [0, 1, 3, 0, 0, 0]'),
#  Text(0.29508196721311475, 0.16666666666666666, 'entropy = 1.5\nsamples = 4\nvalue = [1, 2, 0, 1, 0, 0]'),
#  Text(0.28688524590163933, 0.3888888888888889, 'entropy = 1.459\nsamples = 6\nvalue = [3, 1, 2, 0, 0, 0]'),
#  Text(0.319672131147541, 0.5, 'X[10] <= 11.159\nentropy = 2.074\nsamples = 14\nvalue = [1, 2, 2, 6, 3, 0]'),
#  Text(0.3114754098360656, 0.3888888888888889, 'X[10] <= 10.04\nentropy = 1.658\nsamples = 9\nvalue = [1, 1, 2, 5, 0, 0]'),
#  Text(0.30327868852459017, 0.2777777777777778, 'entropy = 1.5\nsamples = 4\nvalue = [1, 0, 2, 1, 0, 0]'),
#  Text(0.319672131147541, 0.2777777777777778, 'entropy = 0.722\nsamples = 5\nvalue = [0, 1, 0, 4, 0, 0]'),
#  Text(0.32786885245901637, 0.3888888888888889, 'entropy = 1.371\nsamples = 5\nvalue = [0, 1, 0, 1, 3, 0]'),
#  Text(0.36885245901639346, 0.6111111111111112, 'X[10] <= 10.287\nentropy = 1.633\nsamples = 39\nvalue = [0, 2, 19, 13, 5, 0]'),
#  Text(0.3524590163934426, 0.5, 'X[1] <= 0.818\nentropy = 1.141\nsamples = 20\nvalue = [0, 1, 13, 6, 0, 0]'),
#  Text(0.3442622950819672, 0.3888888888888889, 'X[1] <= 0.628\nentropy = 1.248\nsamples = 16\nvalue = [0, 1, 9, 6, 0, 0]'),
#  Text(0.3360655737704918, 0.2777777777777778, 'X[0] <= 8.461\nentropy = 0.544\nsamples = 8\nvalue = [0, 0, 7, 1, 0, 0]'),
#  Text(0.32786885245901637, 0.16666666666666666, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.3442622950819672, 0.16666666666666666, 'entropy = 0.811\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.3524590163934426, 0.2777777777777778, 'entropy = 1.299\nsamples = 8\nvalue = [0, 1, 2, 5, 0, 0]'),
#  Text(0.36065573770491804, 0.3888888888888889, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.38524590163934425, 0.5, 'X[9] <= 0.818\nentropy = 1.786\nsamples = 19\nvalue = [0, 1, 6, 7, 5, 0]'),
#  Text(0.3770491803278688, 0.3888888888888889, 'X[1] <= 0.641\nentropy = 1.782\nsamples = 15\nvalue = [0, 1, 6, 5, 3, 0]'),
#  Text(0.36885245901639346, 0.2777777777777778, 'entropy = 1.0\nsamples = 6\nvalue = [0, 0, 3, 0, 3, 0]'),
#  Text(0.38524590163934425, 0.2777777777777778, 'X[8] <= 3.456\nentropy = 1.352\nsamples = 9\nvalue = [0, 1, 3, 5, 0, 0]'),
#  Text(0.3770491803278688, 0.16666666666666666, 'entropy = 0.971\nsamples = 5\nvalue = [0, 0, 2, 3, 0, 0]'),
#  Text(0.39344262295081966, 0.16666666666666666, 'entropy = 1.5\nsamples = 4\nvalue = [0, 1, 1, 2, 0, 0]'),
#  Text(0.39344262295081966, 0.3888888888888889, 'entropy = 1.0\nsamples = 4\nvalue = [0, 0, 0, 2, 2, 0]'),
#  Text(0.6810963114754098, 0.8333333333333334, 'X[1] <= 0.409\nentropy = 1.585\nsamples = 656\nvalue = [2, 18, 313, 255, 63, 5]'),
#  Text(0.5081967213114754, 0.7222222222222222, 'X[10] <= 9.845\nentropy = 1.691\nsamples = 163\nvalue = [0, 3, 41, 81, 35, 3]'),
#  Text(0.4385245901639344, 0.6111111111111112, 'X[6] <= 47.886\nentropy = 1.265\nsamples = 44\nvalue = [0, 1, 22, 20, 1, 0]'),
#  Text(0.4180327868852459, 0.5, 'X[8] <= 3.317\nentropy = 1.189\nsamples = 12\nvalue = [0, 0, 3, 8, 1, 0]'),
#  Text(0.4098360655737705, 0.3888888888888889, 'X[1] <= 0.34\nentropy = 1.061\nsamples = 8\nvalue = [0, 0, 1, 6, 1, 0]'),
#  Text(0.4016393442622951, 0.2777777777777778, 'entropy = 0.811\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.4180327868852459, 0.2777777777777778, 'entropy = 0.811\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.4262295081967213, 0.3888888888888889, 'entropy = 1.0\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.45901639344262296, 0.5, 'X[3] <= 1.929\nentropy = 1.133\nsamples = 32\nvalue = [0, 1, 19, 12, 0, 0]'),
#  Text(0.4426229508196721, 0.3888888888888889, 'X[8] <= 3.423\nentropy = 0.985\nsamples = 14\nvalue = [0, 0, 6, 8, 0, 0]'),
#  Text(0.4344262295081967, 0.2777777777777778, 'X[6] <= 71.116\nentropy = 1.0\nsamples = 10\nvalue = [0, 0, 5, 5, 0, 0]'),
#  Text(0.4262295081967213, 0.16666666666666666, 'entropy = 0.918\nsamples = 6\nvalue = [0, 0, 2, 4, 0, 0]'),
#  Text(0.4426229508196721, 0.16666666666666666, 'entropy = 0.811\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.45081967213114754, 0.2777777777777778, 'entropy = 0.811\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.47540983606557374, 0.3888888888888889, 'X[5] <= 28.518\nentropy = 1.053\nsamples = 18\nvalue = [0, 1, 13, 4, 0, 0]'),
#  Text(0.4672131147540984, 0.2777777777777778, 'X[2] <= 0.513\nentropy = 1.239\nsamples = 13\nvalue = [0, 1, 8, 4, 0, 0]'),
#  Text(0.45901639344262296, 0.16666666666666666, 'X[2] <= 0.445\nentropy = 1.406\nsamples = 8\nvalue = [0, 1, 4, 3, 0, 0]'),
#  Text(0.45081967213114754, 0.05555555555555555, 'entropy = 1.0\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.4672131147540984, 0.05555555555555555, 'entropy = 1.5\nsamples = 4\nvalue = [0, 1, 2, 1, 0, 0]'),
#  Text(0.47540983606557374, 0.16666666666666666, 'entropy = 0.722\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.48360655737704916, 0.2777777777777778, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.5778688524590164, 0.6111111111111112, 'X[9] <= 0.651\nentropy = 1.666\nsamples = 119\nvalue = [0, 2, 19, 61, 34, 3]'),
#  Text(0.5368852459016393, 0.5, 'X[2] <= 0.495\nentropy = 1.565\nsamples = 42\nvalue = [0, 2, 9, 26, 4, 1]'),
#  Text(0.5163934426229508, 0.3888888888888889, 'X[10] <= 10.836\nentropy = 1.179\nsamples = 33\nvalue = [0, 2, 6, 24, 1, 0]'),
#  Text(0.5, 0.2777777777777778, 'X[8] <= 3.405\nentropy = 1.264\nsamples = 14\nvalue = [0, 1, 5, 8, 0, 0]'),
#  Text(0.4918032786885246, 0.16666666666666666, 'X[3] <= 2.218\nentropy = 0.881\nsamples = 10\nvalue = [0, 0, 3, 7, 0, 0]'),
#  Text(0.48360655737704916, 0.05555555555555555, 'entropy = 1.0\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.5, 0.05555555555555555, 'entropy = 0.65\nsamples = 6\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(0.5081967213114754, 0.16666666666666666, 'entropy = 1.5\nsamples = 4\nvalue = [0, 1, 2, 1, 0, 0]'),
#  Text(0.5327868852459017, 0.2777777777777778, 'X[1] <= 0.246\nentropy = 0.88\nsamples = 19\nvalue = [0, 1, 1, 16, 1, 0]'),
#  Text(0.5245901639344263, 0.16666666666666666, 'entropy = 1.371\nsamples = 5\nvalue = [0, 0, 1, 3, 1, 0]'),
#  Text(0.5409836065573771, 0.16666666666666666, 'X[10] <= 11.749\nentropy = 0.371\nsamples = 14\nvalue = [0, 1, 0, 13, 0, 0]'),
#  Text(0.5327868852459017, 0.05555555555555555, 'entropy = 0.65\nsamples = 6\nvalue = [0, 1, 0, 5, 0, 0]'),
#  Text(0.5491803278688525, 0.05555555555555555, 'entropy = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.5573770491803278, 0.3888888888888889, 'X[4] <= 0.082\nentropy = 1.891\nsamples = 9\nvalue = [0, 0, 3, 2, 3, 1]'),
#  Text(0.5491803278688525, 0.2777777777777778, 'entropy = 1.0\nsamples = 4\nvalue = [0, 0, 0, 2, 2, 0]'),
#  Text(0.5655737704918032, 0.2777777777777778, 'entropy = 1.371\nsamples = 5\nvalue = [0, 0, 3, 0, 1, 1]'),
#  Text(0.6188524590163934, 0.5, 'X[6] <= 63.62\nentropy = 1.566\nsamples = 77\nvalue = [0, 0, 10, 35, 30, 2]'),
#  Text(0.5983606557377049, 0.3888888888888889, 'X[6] <= 53.947\nentropy = 1.466\nsamples = 59\nvalue = [0, 0, 4, 27, 26, 2]'),
#  Text(0.5901639344262295, 0.2777777777777778, 'X[6] <= 38.789\nentropy = 1.317\nsamples = 51\nvalue = [0, 0, 1, 23, 25, 2]'),
#  Text(0.5737704918032787, 0.16666666666666666, 'X[1] <= 0.311\nentropy = 1.283\nsamples = 30\nvalue = [0, 0, 0, 15, 13, 2]'),
#  Text(0.5655737704918032, 0.05555555555555555, 'entropy = 0.949\nsamples = 19\nvalue = [0, 0, 0, 12, 7, 0]'),
#  Text(0.5819672131147541, 0.05555555555555555, 'entropy = 1.435\nsamples = 11\nvalue = [0, 0, 0, 3, 6, 2]'),
#  Text(0.6065573770491803, 0.16666666666666666, 'X[6] <= 46.192\nentropy = 1.201\nsamples = 21\nvalue = [0, 0, 1, 8, 12, 0]'),
#  Text(0.5983606557377049, 0.05555555555555555, 'entropy = 1.299\nsamples = 8\nvalue = [0, 0, 1, 2, 5, 0]'),
#  Text(0.6147540983606558, 0.05555555555555555, 'entropy = 0.996\nsamples = 13\nvalue = [0, 0, 0, 6, 7, 0]'),
#  Text(0.6065573770491803, 0.2777777777777778, 'entropy = 1.406\nsamples = 8\nvalue = [0, 0, 3, 4, 1, 0]'),
#  Text(0.639344262295082, 0.3888888888888889, 'X[6] <= 74.453\nentropy = 1.53\nsamples = 18\nvalue = [0, 0, 6, 8, 4, 0]'),
#  Text(0.6311475409836066, 0.2777777777777778, 'X[6] <= 69.752\nentropy = 1.349\nsamples = 11\nvalue = [0, 0, 5, 5, 1, 0]'),
#  Text(0.6229508196721312, 0.16666666666666666, 'entropy = 1.252\nsamples = 6\nvalue = [0, 0, 4, 1, 1, 0]'),
#  Text(0.639344262295082, 0.16666666666666666, 'entropy = 0.722\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.6475409836065574, 0.2777777777777778, 'entropy = 1.449\nsamples = 7\nvalue = [0, 0, 1, 3, 3, 0]'),
#  Text(0.8539959016393442, 0.7222222222222222, 'X[10] <= 10.984\nentropy = 1.456\nsamples = 493\nvalue = [2, 15, 272, 174, 28, 2]'),
#  Text(0.7663934426229508, 0.6111111111111112, 'X[6] <= 115.429\nentropy = 1.227\nsamples = 398\nvalue = [2, 10, 256, 121, 9, 0]'),
#  Text(0.7581967213114754, 0.5, 'X[6] <= 77.661\nentropy = 1.282\nsamples = 362\nvalue = [2, 10, 220, 121, 9, 0]'),
#  Text(0.7049180327868853, 0.3888888888888889, 'X[10] <= 9.656\nentropy = 1.369\nsamples = 283\nvalue = [2, 9, 157, 106, 9, 0]'),
#  Text(0.6721311475409836, 0.2777777777777778, 'X[7] <= 0.998\nentropy = 1.254\nsamples = 127\nvalue = [1, 7, 83, 35, 1, 0]'),
#  Text(0.6557377049180327, 0.16666666666666666, 'X[7] <= 0.997\nentropy = 1.105\nsamples = 91\nvalue = [0, 4, 65, 21, 1, 0]'),
#  Text(0.6475409836065574, 0.05555555555555555, 'entropy = 1.049\nsamples = 67\nvalue = [0, 1, 47, 18, 1, 0]'),
#  Text(0.6639344262295082, 0.05555555555555555, 'entropy = 1.061\nsamples = 24\nvalue = [0, 3, 18, 3, 0, 0]'),
#  Text(0.6885245901639344, 0.16666666666666666, 'X[10] <= 9.396\nentropy = 1.472\nsamples = 36\nvalue = [1, 3, 18, 14, 0, 0]'),
#  Text(0.680327868852459, 0.05555555555555555, 'entropy = 1.189\nsamples = 12\nvalue = [1, 0, 3, 8, 0, 0]'),
#  Text(0.6967213114754098, 0.05555555555555555, 'entropy = 1.299\nsamples = 24\nvalue = [0, 3, 15, 6, 0, 0]'),
#  Text(0.7377049180327869, 0.2777777777777778, 'X[7] <= 0.997\nentropy = 1.374\nsamples = 156\nvalue = [1, 2, 74, 71, 8, 0]'),
#  Text(0.7213114754098361, 0.16666666666666666, 'X[10] <= 10.269\nentropy = 1.152\nsamples = 90\nvalue = [0, 1, 42, 46, 1, 0]'),
#  Text(0.7131147540983607, 0.05555555555555555, 'entropy = 1.185\nsamples = 48\nvalue = [0, 1, 30, 16, 1, 0]'),
#  Text(0.7295081967213115, 0.05555555555555555, 'entropy = 0.863\nsamples = 42\nvalue = [0, 0, 12, 30, 0, 0]'),
#  Text(0.7540983606557377, 0.16666666666666666, 'X[4] <= 0.093\nentropy = 1.563\nsamples = 66\nvalue = [1, 1, 32, 25, 7, 0]'),
#  Text(0.7459016393442623, 0.05555555555555555, 'entropy = 1.481\nsamples = 51\nvalue = [0, 1, 22, 23, 5, 0]'),
#  Text(0.7622950819672131, 0.05555555555555555, 'entropy = 1.426\nsamples = 15\nvalue = [1, 0, 10, 2, 2, 0]'),
#  Text(0.8114754098360656, 0.3888888888888889, 'X[10] <= 10.477\nentropy = 0.795\nsamples = 79\nvalue = [0, 1, 63, 15, 0, 0]'),
#  Text(0.8032786885245902, 0.2777777777777778, 'X[4] <= 0.104\nentropy = 0.671\nsamples = 74\nvalue = [0, 0, 61, 13, 0, 0]'),
#  Text(0.7868852459016393, 0.16666666666666666, 'X[7] <= 0.999\nentropy = 0.736\nsamples = 58\nvalue = [0, 0, 46, 12, 0, 0]'),
#  Text(0.7786885245901639, 0.05555555555555555, 'entropy = 0.772\nsamples = 53\nvalue = [0, 0, 41, 12, 0, 0]'),
#  Text(0.7950819672131147, 0.05555555555555555, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.819672131147541, 0.16666666666666666, 'X[1] <= 0.7\nentropy = 0.337\nsamples = 16\nvalue = [0, 0, 15, 1, 0, 0]'),
#  Text(0.8114754098360656, 0.05555555555555555, 'entropy = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.8278688524590164, 0.05555555555555555, 'entropy = 0.722\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.819672131147541, 0.2777777777777778, 'entropy = 1.522\nsamples = 5\nvalue = [0, 1, 2, 2, 0, 0]'),
#  Text(0.7745901639344263, 0.5, 'entropy = 0.0\nsamples = 36\nvalue = [0, 0, 36, 0, 0, 0]'),
#  Text(0.9415983606557377, 0.6111111111111112, 'X[1] <= 0.746\nentropy = 1.708\nsamples = 95\nvalue = [0, 5, 16, 53, 19, 2]'),
#  Text(0.9118852459016393, 0.5, 'X[10] <= 11.783\nentropy = 1.575\nsamples = 83\nvalue = [0, 1, 14, 48, 18, 2]'),
#  Text(0.8770491803278688, 0.3888888888888889, 'X[10] <= 11.353\nentropy = 1.448\nsamples = 46\nvalue = [0, 1, 10, 28, 7, 0]'),
#  Text(0.860655737704918, 0.2777777777777778, 'X[5] <= 27.301\nentropy = 1.476\nsamples = 27\nvalue = [0, 1, 10, 14, 2, 0]'),
#  Text(0.8524590163934426, 0.16666666666666666, 'X[3] <= 2.152\nentropy = 1.562\nsamples = 22\nvalue = [0, 1, 9, 10, 2, 0]'),
#  Text(0.8442622950819673, 0.05555555555555555, 'entropy = 0.811\nsamples = 8\nvalue = [0, 0, 6, 2, 0, 0]'),
#  Text(0.860655737704918, 0.05555555555555555, 'entropy = 1.611\nsamples = 14\nvalue = [0, 1, 3, 8, 2, 0]'),
#  Text(0.8688524590163934, 0.16666666666666666, 'entropy = 0.722\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.8934426229508197, 0.2777777777777778, 'X[10] <= 11.552\nentropy = 0.831\nsamples = 19\nvalue = [0, 0, 0, 14, 5, 0]'),
#  Text(0.8852459016393442, 0.16666666666666666, 'entropy = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.9016393442622951, 0.16666666666666666, 'X[9] <= 0.631\nentropy = 1.0\nsamples = 10\nvalue = [0, 0, 0, 5, 5, 0]'),
#  Text(0.8934426229508197, 0.05555555555555555, 'entropy = 0.811\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.9098360655737705, 0.05555555555555555, 'entropy = 0.918\nsamples = 6\nvalue = [0, 0, 0, 2, 4, 0]'),
#  Text(0.9467213114754098, 0.3888888888888889, 'X[9] <= 0.604\nentropy = 1.575\nsamples = 37\nvalue = [0, 0, 4, 20, 11, 2]'),
#  Text(0.9262295081967213, 0.2777777777777778, 'X[4] <= 0.051\nentropy = 0.684\nsamples = 11\nvalue = [0, 0, 2, 9, 0, 0]'),
#  Text(0.9180327868852459, 0.16666666666666666, 'entropy = 1.0\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.9344262295081968, 0.16666666666666666, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.9672131147540983, 0.2777777777777778, 'X[4] <= 0.072\nentropy = 1.619\nsamples = 26\nvalue = [0, 0, 2, 11, 11, 2]'),
#  Text(0.9508196721311475, 0.16666666666666666, 'X[9] <= 0.72\nentropy = 1.611\nsamples = 14\nvalue = [0, 0, 1, 3, 8, 2]'),
#  Text(0.9426229508196722, 0.05555555555555555, 'entropy = 1.371\nsamples = 5\nvalue = [0, 0, 1, 3, 1, 0]'),
#  Text(0.9590163934426229, 0.05555555555555555, 'entropy = 0.764\nsamples = 9\nvalue = [0, 0, 0, 0, 7, 2]'),
#  Text(0.9836065573770492, 0.16666666666666666, 'X[5] <= 22.512\nentropy = 1.189\nsamples = 12\nvalue = [0, 0, 1, 8, 3, 0]'),
#  Text(0.9754098360655737, 0.05555555555555555, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.9918032786885246, 0.05555555555555555, 'entropy = 1.449\nsamples = 7\nvalue = [0, 0, 1, 3, 3, 0]'),
#  Text(0.9713114754098361, 0.5, 'X[1] <= 0.894\nentropy = 1.784\nsamples = 12\nvalue = [0, 4, 2, 5, 1, 0]'),
#  Text(0.9631147540983607, 0.3888888888888889, 'entropy = 1.252\nsamples = 6\nvalue = [0, 1, 0, 4, 1, 0]'),
#  Text(0.9795081967213115, 0.3888888888888889, 'entropy = 1.459\nsamples = 6\nvalue = [0, 3, 2, 1, 0, 0]')]

# %%
y_prediction2=model_with_best_params.predict(X_test)

# %%
accuracy_score(y_test,y_prediction2)
# Out:
# 0.48775055679287305

# %%
#logistic regression, SVM ,  going forward(RF,XB,GB,AB)

# %% [markdown]
# ### for regressor model in hyperpyrameter tuning use criterion="SME" (squared mean error) this is all for regressor

# %%
#Implement the decision tree regressor
dataset:https://archive.ics.uci.edu/ml/datasets/individual+household+electric+power+consumption
        
take_refrence_from_here:https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html#sklearn.tree.DecisionTreeRegressor

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
Rf_model=RandomForestClassifier()

# %%
Rf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rf=Rf_model.predict(X_test)

# %%
accuracy_score(y_test,y_pred_rf)
# Out:
# 0.6057906458797327

# %%
# we are tuning three hyperparameters right now, we are passing the different values for both parameters
grid_param = {
    "n_estimators" : [90,100,115,130],
    'criterion': ['gini', 'entropy'],
    'max_depth' : range(2,20,1),
    'min_samples_leaf' : range(1,10,1),
    'min_samples_split': range(2,10,1),
    'max_features' : ['auto','log2']
}

# %%
from sklearn.model_selection import GridSearchCV
grid_searh=GridSearchCV(estimator=Rf_model,param_grid=grid_param,cv=3,verbose=2,n_jobs=-1)

# %%
grid_searh.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 20736 candidates, totalling 62208 fits
# KeyboardInterrupt

# %%
grid_searh.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 14,
#  'max_features': 'log2',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 115}

# %%
Rf_model_with_best_params=RandomForestClassifier(criterion='gini',max_depth= 14,max_features= 'log2',min_samples_leaf= 1,min_samples_split= 2,n_estimators=115)

# %%
Rf_model_with_best_params.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=14, max_features='log2', n_estimators=115)

# %%
y_predict_rf_bp=Rf_model_with_best_params.predict(X_test)

# %%
accuracy_score(y_test,y_predict_rf_bp)
# Out:
# 0.6102449888641426

# %% [markdown]
# ## random forest is a bagging technic but it only consider decision tree model so use different model we can call bagging classifier class

# %%
# here we are using support vector classifier in bagging technic
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.datasets import make_classification

model_bagging_svc = BaggingClassifier(base_estimator=SVC(),n_estimators=50, random_state=0).fit(X_train,y_train)

# %%
y_predict_bagging=model_bagging_svc.predict(X_test)

# %%
accuracy_score(y_test,y_predict_bagging)
# Out:
# 0.4766146993318486

# %%
#use bagging classiifer and regressor, extra tree classifier and regressor, voting classifer and regressor and random forest classifier and regressor on top of House hold consumpltion data and cencus data

data link: https://archive.ics.uci.edu/ml/datasets/individual+household+electric+power+consumption
        https://archive.ics.uci.edu/ml/datasets/census+income
    
sklearn_link:https://scikit-learn.org/stable/modules/classes.html#module-sklearn.ensemble
